# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
Data=pd.read_csv('Merged File.csv')

# %%
Data.head(5)
# Out:
#    id  Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
Data.tail(5)
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 24694  24694               3.0         No                      5.0
# 24695  24695               8.0        Yes                      2.0
# 24696  24696               2.0         No                      4.0
# 24697  24697               3.0         No                      4.0
# 24698  24698               NaN        Yes                      1.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 24694            5.0                        No                  9.0
# 24695            1.0                       Yes                  0.0
# 24696            3.0                        No                  9.0
# 24697            4.0                        No                 11.0
# 24698            1.0                       Yes                  1.0
#
#        Post_frequency Personality
# 24694             6.0         NaN
# 24695             0.0         NaN
# 24696             7.0         NaN
# 24697             9.0         NaN
# 24698             0.0         NaN

# %%
Data.shape
# Out:
# (24699, 9)

# %%
Data.columns
# Out:
# Index(['id', 'Time_spent_Alone', 'Stage_fear', 'Social_event_attendance',
#        'Going_outside', 'Drained_after_socializing', 'Friends_circle_size',
#        'Post_frequency', 'Personality'],
#       dtype='object')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24699 entries, 0 to 24698
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         24699 non-null  int64
#  1   Time_spent_Alone           23084 non-null  float64
#  2   Stage_fear                 22208 non-null  object
#  3   Social_event_attendance    23122 non-null  float64
#  4   Going_outside              22767 non-null  float64
#  5   Drained_after_socializing  23118 non-null  object
#  6   Friends_circle_size        23295 non-null  float64
#  7   Post_frequency             23027 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
Data.describe()
# Out:
#                  id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# count  24699.000000      23084.000000             23122.000000   22767.000000
# mean   12349.000000          3.132559                 5.270824       4.042693
# std     7130.131485          2.999230                 2.754491       2.058194
# min        0.000000          0.000000                 0.000000       0.000000
# 25%     6174.500000          1.000000                 3.000000       3.000000
# 50%    12349.000000          2.000000                 5.000000       4.000000
# 75%    18523.500000          4.000000                 8.000000       6.000000
# max    24698.000000         11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count         23295.000000    23027.000000
# mean              7.999657        4.993833
# std               4.215721        2.876184
# min               0.000000        0.000000
# 25%               5.000000        3.000000
# 50%               8.000000        5.000000
# 75%              12.000000        7.000000
# max              15.000000       10.000000

# %%
Data.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone             1615
# Stage_fear                   2491
# Social_event_attendance      1577
# Going_outside                1932
# Drained_after_socializing    1581
# Friends_circle_size          1404
# Post_frequency               1672
# Personality                  6175
# dtype: int64

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
Data.nunique()
# Out:
# id                           24699
# Time_spent_Alone                12
# Stage_fear                       2
# Social_event_attendance         11
# Going_outside                    8
# Drained_after_socializing        2
# Friends_circle_size             16
# Post_frequency                  11
# Personality                      2
# dtype: int64

# %%
plt.figure(figsize=(20,12))

sns.pairplot(Data)

# %%
# Catgeorical and Numerical Features 

Cat_columns=[feature for feature in Data.columns if Data[feature].dtypes=='object']
Num_columns=[feature for feature in Data.columns if Data[feature].dtypes!='object']

# %%
Cat_columns
# Out:
# ['Stage_fear', 'Drained_after_socializing', 'Personality']

# %%
Num_columns
# Out:
# ['id',
#  'Time_spent_Alone',
#  'Social_event_attendance',
#  'Going_outside',
#  'Friends_circle_size',
#  'Post_frequency']

# %%
Data[Cat_columns].head(5)
# Out:
#   Stage_fear Drained_after_socializing Personality
# 0         No                        No   Extrovert
# 1         No                        No   Extrovert
# 2        Yes                       NaN   Introvert
# 3         No                        No   Extrovert
# 4         No                        No   Extrovert

# %%
for i in Cat_columns:
    ax=sns.countplot(Data, x=i)
    for container in ax.containers:
        ax.bar_label(container)
    plt.xlabel(i)
    plt.show()

# %%
Data[Num_columns].head(5)
# Out:
#    id  Time_spent_Alone  Social_event_attendance  Going_outside  \
# 0   0               0.0                      6.0            4.0
# 1   1               1.0                      7.0            3.0
# 2   2               6.0                      1.0            0.0
# 3   3               3.0                      7.0            3.0
# 4   4               1.0                      4.0            4.0
#
#    Friends_circle_size  Post_frequency
# 0                 15.0             5.0
# 1                 10.0             8.0
# 2                  3.0             0.0
# 3                 11.0             5.0
# 4                 13.0             NaN

# %%
plt.pie(Data['Stage_fear'].value_counts(), labels=['No', 'Yes'], colors=['blue', 'violet'], explode=[0,0.2], shadow=True, autopct='%1.1f')
plt.show()

# %%
Data['Stage_fear'].value_counts()
# Out:
# No     16845
# Yes     5363
# Name: Stage_fear, dtype: int64

# %%
plt.pie(x=Data['Drained_after_socializing'].value_counts(), labels=['No', 'Yes'], colors=['orange', 'blue'], explode=[0, 0.2], shadow=True, autopct='%1.1f')
plt.show()

# %%
plt.pie(x=Data['Personality'].value_counts(), labels=['Introvert', 'Extrovert'], colors=['pink', 'green'], autopct='%1.1f', explode=[0, 0.2], shadow=True)
plt.show()

# %%
Data['Personality'].value_counts()
# Out:
# Extrovert    13699
# Introvert     4825
# Name: Personality, dtype: int64

# %%
Data['Drained_after_socializing'].value_counts()
# Out:
# No     17750
# Yes     5368
# Name: Drained_after_socializing, dtype: int64

# %%
for i in Num_columns:
    sns.distplot(x=Data[i])
    plt.xlabel(i)
    plt.show()

# %%
for i in Num_columns:
    sns.histplot(x=Data[i], kde=True)
    plt.xlabel(i)
    plt.show()

# %%
for i in Num_columns:
    sns.histplot(x=Data[i], kde=True, hue=Data['Personality'])
    plt.xlabel(i)
    plt.show()

# %%
for i in Cat_columns:
    ax=sns.countplot(Data, x=i, hue=Data['Personality'])
    for container in ax.containers:
        ax.bar_label(container)
    plt.xlabel(i)
    plt.show()

# %%
for i in Num_columns:
    sns.scatterplot(Data[i])
    plt.xlabel(i)
    plt.show()

# %%
for i in Num_columns:
    sns.boxplot(x=Data[i])
    plt.xlabel(i)
    plt.show()

# %%
sns.heatmap(Data[Num_columns].corr(), fmt='.2f', linewidth=0.2, annot=True)
# Out:
# <Axes: >

# %%
Data.corr()
# Out:
#                                id  Time_spent_Alone  Social_event_attendance  \
# id                       1.000000         -0.002992                 0.004762
# Time_spent_Alone        -0.002992          1.000000                -0.629211
# Social_event_attendance  0.004762         -0.629211                 1.000000
# Going_outside            0.002571         -0.637970                 0.581343
# Friends_circle_size      0.003836         -0.594393                 0.564144
# Post_frequency           0.004977         -0.610425                 0.564195
#
#                          Going_outside  Friends_circle_size  Post_frequency
# id                            0.002571             0.003836        0.004977
# Time_spent_Alone             -0.637970            -0.594393       -0.610425
# Social_event_attendance       0.581343             0.564144        0.564195
# Going_outside                 1.000000             0.547377        0.574042
# Friends_circle_size           0.547377             1.000000        0.523387
# Post_frequency                0.574042             0.523387        1.000000

# %%
Data.isnull().sum()
# Out:
# id                              0
# Time_spent_Alone             1615
# Stage_fear                   2491
# Social_event_attendance      1577
# Going_outside                1932
# Drained_after_socializing    1581
# Friends_circle_size          1404
# Post_frequency               1672
# Personality                  6175
# dtype: int64

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24699 entries, 0 to 24698
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         24699 non-null  int64
#  1   Time_spent_Alone           23084 non-null  float64
#  2   Stage_fear                 22208 non-null  object
#  3   Social_event_attendance    23122 non-null  float64
#  4   Going_outside              22767 non-null  float64
#  5   Drained_after_socializing  23118 non-null  object
#  6   Friends_circle_size        23295 non-null  float64
#  7   Post_frequency             23027 non-null  float64
#  8   Personality                18524 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
for feature in Num_columns:
    if Data[feature].isnull().any():   # only if NaN exists
        median_value = Data[feature].median()
        Data[feature].fillna(median_value, inplace=True)

# %%
for feature in Cat_columns:
    if Data[feature].isnull().any():   # only if NaN exists
        mode_value = Data[feature].mode()[0]
        Data[feature].fillna(mode_value, inplace=True)

# %%
Data.isnull().sum()
# Out:
# id                           0
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
Data.isnull()
# Out:
#           id  Time_spent_Alone  Stage_fear  Social_event_attendance  \
# 0      False             False       False                    False
# 1      False             False       False                    False
# 2      False             False       False                    False
# 3      False             False       False                    False
# 4      False             False       False                    False
# ...      ...               ...         ...                      ...
# 24694  False             False       False                    False
# 24695  False             False       False                    False
# 24696  False             False       False                    False
# 24697  False             False       False                    False
# 24698  False             False       False                    False
#
#        Going_outside  Drained_after_socializing  Friends_circle_size  \
# 0              False                      False                False
# 1              False                      False                False
# 2              False                      False                False
# 3              False                      False                False
# 4              False                      False                False
# ...              ...                        ...                  ...
# 24694          False                      False                False
# 24695          False                      False                False
# 24696          False                      False                False
# 24697          False                      False                False
# 24698          False                      False                False
#
#        Post_frequency  Personality
# 0               False        False
# 1               False        False
# 2               False        False
# 3               False        False
# 4               False        False
# ...               ...          ...
# 24694           False        False
# 24695           False        False
# 24696           False        False
# 24697           False        False
# 24698           False        False
#
# [24699 rows x 9 columns]

# %%
Data.corr()
# Out:
#                                id  Time_spent_Alone  Social_event_attendance  \
# id                       1.000000         -0.003550                 0.004529
# Time_spent_Alone        -0.003550          1.000000                -0.582597
# Social_event_attendance  0.004529         -0.582597                 1.000000
# Going_outside            0.002506         -0.586149                 0.535799
# Friends_circle_size      0.003726         -0.553924                 0.527784
# Post_frequency           0.004797         -0.562399                 0.521525
#
#                          Going_outside  Friends_circle_size  Post_frequency
# id                            0.002506             0.003726        0.004797
# Time_spent_Alone             -0.586149            -0.553924       -0.562399
# Social_event_attendance       0.535799             0.527784        0.521525
# Going_outside                 1.000000             0.506056        0.524475
# Friends_circle_size           0.506056             1.000000        0.486491
# Post_frequency                0.524475             0.486491        1.000000

# %%
for i in Cat_columns:
    print(Data[i].value_counts())
# Out:
# No     19336
# Yes     5363
# Name: Stage_fear, dtype: int64
# No     19331
# Yes     5368
# Name: Drained_after_socializing, dtype: int64
# Extrovert    19874
# Introvert     4825
# Name: Personality, dtype: int64

# %%
Data['Personality']=Data['Personality'].replace({'Introvert':0, 'Extrovert':1})

# %%
Data['Personality'].value_counts()
# Out:
# 1    19874
# 0     4825
# Name: Personality, dtype: int64

# %%
X=Data.drop('Personality', axis=1)
y=Data['Personality']

# %%
X
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 24694  24694               3.0         No                      5.0
# 24695  24695               8.0        Yes                      2.0
# 24696  24696               2.0         No                      4.0
# 24697  24697               3.0         No                      4.0
# 24698  24698               2.0        Yes                      1.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# 1                3.0                        No                 10.0
# 2                0.0                        No                  3.0
# 3                3.0                        No                 11.0
# 4                4.0                        No                 13.0
# ...              ...                       ...                  ...
# 24694            5.0                        No                  9.0
# 24695            1.0                       Yes                  0.0
# 24696            3.0                        No                  9.0
# 24697            4.0                        No                 11.0
# 24698            1.0                       Yes                  1.0
#
#        Post_frequency
# 0                 5.0
# 1                 8.0
# 2                 0.0
# 3                 5.0
# 4                 5.0
# ...               ...
# 24694             6.0
# 24695             0.0
# 24696             7.0
# 24697             9.0
# 24698             0.0
#
# [24699 rows x 8 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 24694    1
# 24695    1
# 24696    1
# 24697    1
# 24698    1
# Name: Personality, Length: 24699, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=23)

# %%
X_train.shape, y_train.shape
# Out:
# ((17289, 8), (17289,))

# %%
X_test.shape, y_test.shape
# Out:
# ((7410, 8), (7410,))

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
Scaler=StandardScaler()
OHE=OneHotEncoder(drop='first')

# %%
preprocessor=ColumnTransformer([
    ('OneHotEncoder', OHE, ['Stage_fear', 'Drained_after_socializing']),
    ('StandardScaler', Scaler, ['id', 'Time_spent_Alone', 'Social_event_attendance', 'Going_outside', 'Friends_circle_size', 'Friends_circle_size'])
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OneHotEncoder', OneHotEncoder(drop='first'),
#                                  ['Stage_fear', 'Drained_after_socializing']),
#                                 ('StandardScaler', StandardScaler(),
#                                  ['id', 'Time_spent_Alone',
#                                   'Social_event_attendance', 'Going_outside',
#                                   'Friends_circle_size',
#                                   'Friends_circle_size'])])

# %%
X_train=preprocessor.fit_transform(X_train)
X_test=preprocessor.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.        ,  0.        ,  0.05201059, ...,  0.99049227,
#          0.48916084,  0.48916084],
#        [ 0.        ,  0.        ,  0.3861701 , ...,  0.48541571,
#         -0.48709979, -0.48709979],
#        [ 0.        ,  0.        , -1.29236588, ...,  1.49556883,
#         -0.73116495, -0.73116495],
#        ...,
#        [ 0.        ,  0.        , -0.15889682, ...,  0.99049227,
#          0.24509568,  0.24509568],
#        [ 1.        ,  0.        , -0.43100819, ..., -2.0399671 ,
#         -1.95149075, -1.95149075],
#        [ 0.        ,  0.        , -0.4969959 , ...,  0.48541571,
#          0.733226  ,  0.733226  ]])

# %%
X_test
# Out:
# array([[ 0.        ,  0.        , -0.79302605, ..., -0.01966086,
#          0.48916084,  0.48916084],
#        [ 0.        ,  0.        ,  0.79222667, ...,  0.48541571,
#          0.733226  ,  0.733226  ],
#        [ 0.        ,  0.        ,  1.0235354 , ..., -0.01966086,
#          1.46542148,  1.46542148],
#        ...,
#        [ 0.        ,  0.        ,  0.55078763, ...,  1.49556883,
#          0.24509568,  0.24509568],
#        [ 0.        ,  0.        , -0.03930289, ...,  0.48541571,
#          1.70948664,  1.70948664],
#        [ 1.        ,  1.        ,  1.61264104, ..., -0.52473742,
#         -0.73116495, -0.73116495]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix, roc_auc_score

# %%
def model_evaluate(true, predicted):
    accuracy=accuracy_score(true, predicted)
    f1=f1_score(true, predicted)
    precision=precision_score(true, predicted)
    recall=recall_score(true, predicted)
    roc_auc=roc_auc_score(true, predicted)
    return accuracy, f1, precision, recall, roc_auc

# %%
models={
    'Logistic Regression' : LogisticRegression(),
    'Naive Bayes' : BernoulliNB(),
    'Decision Tree Classifier' : DecisionTreeClassifier(),
    'Random Forest Classifier' : RandomForestClassifier(),
    'Gradient Boosting Classifier' : GradientBoostingClassifier(),
    'AdaBoost Classifier' : AdaBoostClassifier(),
    'KNN' : KNeighborsClassifier(),
    'SVM' : SVC()
    
}

# %%
models
# Out:
# {'Logistic Regression': LogisticRegression(),
#  'Naive Bayes': BernoulliNB(),
#  'Decision Tree Classifier': DecisionTreeClassifier(),
#  'Random Forest Classifier': RandomForestClassifier(),
#  'Gradient Boosting Classifier': GradientBoostingClassifier(),
#  'AdaBoost Classifier': AdaBoostClassifier(),
#  'KNN': KNeighborsClassifier(),
#  'SVM': SVC()}

# %%
model_list=[]
acc_list=[]
model_objs=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train, y_train)

    y_train_pred=model.predict(X_train)
    y_test_pred=model.predict(X_test)

    model_train_acc, model_train_f1, model_train_precision, model_train_recall, model_train_roc=model_evaluate(y_train, y_train_pred)
    model_test_acc, model_test_f1, model_test_precision, model_test_recall, model_test_roc=model_evaluate(y_test, y_test_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print("Model Performance for Training Data")
    print(" - Accuracy Score : {:.4f}".format(model_train_acc))
    print(" - F1 Score : {:.4f}".format(model_train_f1))
    print(" - Precision Score : {:.4f}".format(model_train_precision))
    print(" - Recall Score : {:.4f}".format(model_train_recall))
    print(" - Roc Auc Score : {:.4f}".format(model_train_roc))


    print("-------------------------------------------------------------------")

    print("Model Performance for Testing Data")
    print(" - Accuracy Score : {:.4f}".format(model_test_acc))
    print(" - F1 Score : {:.4f}".format(model_test_f1))
    print(" - Precision Score : {:.4f}".format(model_test_precision))
    print(" - Recall Score : {:.4f}".format(model_test_recall))
    print(" - Roc Auc Score : {:.4f}".format(model_test_roc))

    model_objs.append(model)


    acc_list.append(model_test_acc)

    print("\n")
    print("$"*45)
    print("\n")
# Out:
# Logistic Regression
# Model Performance for Training Data
#  - Accuracy Score : 0.9457
#  - F1 Score : 0.9664
#  - Precision Score : 0.9610
#  - Recall Score : 0.9719
#  - Roc Auc Score : 0.9053
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9460
#  - F1 Score : 0.9668
#  - Precision Score : 0.9609
#  - Recall Score : 0.9728
#  - Roc Auc Score : 0.9033
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
# Naive Bayes
# Model Performance for Training Data
#  - Accuracy Score : 0.9122
#  - F1 Score : 0.9433
#  - Precision Score : 0.9798
#  - Recall Score : 0.9095
#  - Roc Auc Score : 0.9164
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9092
#  - F1 Score : 0.9415
#  - Precision Score : 0.9810
#  - Recall Score : 0.9051
#  - Roc Auc Score : 0.9157
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
# Decision Tree Classifier
# Model Performance for Training Data
#  - Accuracy Score : 1.0000
#  - F1 Score : 1.0000
#  - Precision Score : 1.0000
#  - Recall Score : 1.0000
#  - Roc Auc Score : 1.0000
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9549
#  - F1 Score : 0.9721
#  - Precision Score : 0.9707
#  - Recall Score : 0.9736
#  - Roc Auc Score : 0.9251
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
# Random Forest Classifier
# Model Performance for Training Data
#  - Accuracy Score : 0.9999
#  - F1 Score : 1.0000
#  - Precision Score : 1.0000
#  - Recall Score : 0.9999
#  - Roc Auc Score : 1.0000
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9753
#  - F1 Score : 0.9847
#  - Precision Score : 0.9835
#  - Recall Score : 0.9860
#  - Roc Auc Score : 0.9583
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
# Gradient Boosting Classifier
# Model Performance for Training Data
#  - Accuracy Score : 0.9772
#  - F1 Score : 0.9858
#  - Precision Score : 0.9850
#  - Recall Score : 0.9866
#  - Roc Auc Score : 0.9627
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9765
#  - F1 Score : 0.9855
#  - Precision Score : 0.9840
#  - Recall Score : 0.9870
#  - Roc Auc Score : 0.9598
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
# AdaBoost Classifier
# Model Performance for Training Data
#  - Accuracy Score : 0.9737
#  - F1 Score : 0.9837
#  - Precision Score : 0.9810
#  - Recall Score : 0.9865
#  - Roc Auc Score : 0.9541
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9753
#  - F1 Score : 0.9848
#  - Precision Score : 0.9811
#  - Recall Score : 0.9885
#  - Roc Auc Score : 0.9543
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
# KNN
# Model Performance for Training Data
#  - Accuracy Score : 0.9721
#  - F1 Score : 0.9827
#  - Precision Score : 0.9813
#  - Recall Score : 0.9840
#  - Roc Auc Score : 0.9538
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9672
#  - F1 Score : 0.9798
#  - Precision Score : 0.9771
#  - Recall Score : 0.9825
#  - Roc Auc Score : 0.9428
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#
#
# SVM
# Model Performance for Training Data
#  - Accuracy Score : 0.9744
#  - F1 Score : 0.9841
#  - Precision Score : 0.9827
#  - Recall Score : 0.9855
#  - Roc Auc Score : 0.9573
# -------------------------------------------------------------------
# Model Performance for Testing Data
#  - Accuracy Score : 0.9748
#  - F1 Score : 0.9844
#  - Precision Score : 0.9825
#  - Recall Score : 0.9863
#  - Roc Auc Score : 0.9563
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

# %%
pd.DataFrame(list(zip(model_list, acc_list)), columns=['Model Name', 'Accuracy Score']).sort_values(by=["Accuracy Score"],ascending=False)
# Out:
#                      Model Name  Accuracy Score
# 4  Gradient Boosting Classifier        0.976518
# 3      Random Forest Classifier        0.975304
# 5           AdaBoost Classifier        0.975304
# 7                           SVM        0.974764
# 6                           KNN        0.967206
# 2      Decision Tree Classifier        0.954926
# 0           Logistic Regression        0.946019
# 1                   Naive Bayes        0.909177
